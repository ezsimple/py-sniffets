# %% [markdown]
# 머신러닝 (Python 3.10.14)에 연결됨

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19     # return f'{hours_value}시간'
#      20
#      21 # 원형 그래프 그리기
#      22 plt.figure(figsize=(8, 8))
# ---> 23 wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=None, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향
#      25 # 원 둘레에 시간(0~24시) 표시
#      26 ax = plt.gca()  # 현재 축 가져오기
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=0, colors=colors, counterclock=True)  # 색깔 지정 및 시계 방향

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=0, colors=colors, counterclock=False)  # 색깔 지정 및 시계 방향


# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=-90, colors=colors, counterclock=False)  # 색깔 지정 및 시계 방향


# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic') 						## 이 두 줄을
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다.

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)  # 색깔 지정 및 시계 방향


# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (원 둘레에 시간 표시 및 활동명 표시)')

# 그래프 보여주기
plt.show()

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 수면을 22시부터 06시까지로 지정하고, 기타와 결합
# 22시부터 24시까지 수면 (2시간) + 00시부터 06시까지 수면 (6시간) = 총 8시간
# 기타는 나머지 시간
activities_combined = ['수면(22시~06시)', '일', '식사', '운동', '휴식', '기타']
hours_combined = [8, 8, 2, 1, 2, 3]
colors_combined = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours_combined)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours_combined, labels=None, autopct=time_autopct, startangle=90, colors=colors_combined, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities_combined)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 수면을 22시부터 06시까지로 지정하고, 기타와 결합
# 22시부터 24시까지 수면 (2시간) + 00시부터 06시까지 수면 (6시간) = 총 8시간
# 기타는 나머지 시간
activities_combined = ['수면(22시~06시)', '일', '식사', '운동', '휴식', '기타']
hours_combined = [8, 8, 2, 1, 2, 3]
colors_combined = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours_combined)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours_combined, labels=None, autopct=time_autopct, startangle=90, colors=colors_combined, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities_combined)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities_combined)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '기타']
hours = [8, 8, 2, 1, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '수면']
hours = [6, 8, 2, 1, 3, 2]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '수면']
hours = [6, 8, 2, 1, 3, 2]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '수면']
hours = [6, 8, 1, 2, 7, 2]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '수면']
hours = [6, 8, 1, 2, 7, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '']
hours = [6, 8, 1, 2, 7, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '']
hours = [8, 8, 1, 2, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '']
hours = [6, 19, 1, 2, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '일', '식사', '운동', '휴식', '']
hours = [7, 9, 1, 2, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '일', '식사','휴식','']
hours = [6, 1, 10, 1, 4, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '일', '식사','휴식','']
hours = [6, 1, 11, 1, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '오전업무', '식사', '오후업무', '식사','휴식','']
hours = [6, 1, 5, 1, 5, 1, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '오전업무', '식사', '오후업무', '식사','휴식','']
hours = [6, 1, 5, 1, 5, 1, 3, 2]
sleep_color = '#ff9999'
colors = [sleep_color, '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#af02f1', '#beabcd', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '오전업무', '식사', '오후업무', '식사','휴식','']
hours = [6, 1, 5, 1, 5, 1, 3, 2]
sleep_color = '#ff9999'
meal_color = '#66b3ff'
colors = [sleep_color, meal_color, '#99ff99', meal_color, '#c2c2f0', meal_color, '#00abcd', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '오전업무', '식사', '오후업무', '식사','휴식','']
hours = [6, 1, 5, 1, 6, 1, 2, 2]
sleep_color = '#ff9999'
meal_color = '#66b3ff'
colors = [sleep_color, meal_color, '#99ff99', meal_color, '#c2c2f0', meal_color, '#00abcd', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '오전업무', '식사', '오후업무', '식사','휴식','']
hours = [6, 1, 5, 1, 6, 1, 2, 2]
sleep_color = '#ff9999'
meal_color = '#66b3ff'
business_color = '#99ff99'
colors = [sleep_color, meal_color, business_color, meal_color, business_color, meal_color, '#00abcd', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사','휴식','']
hours = [6, 1, 1, 4, 1, 5, 1, 1, 2, 2]
sleep_color = '#ff9999'
meal_color = '#66b3ff'
business_color = '#99ff99'
commute_color = '#96f696'
colors = [sleep_color, meal_color, commute_color, business_color, meal_color, business_color, commute_color, meal_color, '#00abcd', sleep_color]  # 색깔 지정

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정


# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = '#ff9999'
    MEAL = '#66b3ff'
    BUSINESS = '#99ff99'
    COMMUTE = '#96f696'
    REST = '#00abcd'

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [6, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표 (22시~06시 수면 및 기타 합침)')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정


# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = '#ff9999'
    MEAL = '#66b3ff'
    BUSINESS = '#99ff99'
    COMMUTE = '#96f696'
    REST = '#00abcd'

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [6, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    colors = list(mcolors.TABLEAU_COLORS.values())
    while len(colors) < num_colors:
        colors.extend(list(mcolors.TABLEAU_COLORS.values()))
    return colors[:num_colors]

rainbow_colors = rainbow_colors(6)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[4]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.CSS4_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(6)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[4]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.CSS4_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(6)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:26
#      23 rainbow_colors = rainbow_colors(6)
#      25 # 색깔을 enum으로 선언
# ---> 26 class Color(Enum):
#      27     SLEEP = rainbow_colors[0]   # 수면
#      28     MEAL = rainbow_colors[1]    # 식사
#
# File /Users/mkeasy/daily_sched.py:31
#      29 BUSINESS = rainbow_colors[2] # 업무
#      30 COMMUTE = rainbow_colors[3] # 출퇴근
# ---> 31 REST = rainbow_colors[6]    # 휴식
#      32 EXERCISE = rainbow_colors[5]
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.CSS4_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.CSS3_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:23
#      19         pastel_colors.extend(pastel_colors)
#      20     return pastel_colors[:num_colors]
# ---> 23 rainbow_colors = rainbow_colors(7)
#      25 # 색깔을 enum으로 선언
#      26 class Color(Enum):
#
# File /Users/mkeasy/daily_sched.py:13
#      12 def rainbow_colors(num_colors):
# ---> 13     base_colors = list(mcolors.CSS3_COLORS.values())
#      14     pastel_colors = []
#      15     for color in base_colors:
#
# AttributeError: module 'matplotlib.colors' has no attribute 'CSS3_COLORS'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.TABLEAU_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.5)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    pastel_colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        pastel_colors.append(pastel_color)
    while len(pastel_colors) < num_colors:
        pastel_colors.extend(pastel_colors)
    return pastel_colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    while len(colors) < num_colors:
        colors.extend(colors)
    return colors[:num_colors]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Users/mkeasy/daily_sched.py:22
#      18         colors.append(pastel_color)
#      19     return colors
# ---> 22 rainbow_colors = rainbow_colors(7)
#      24 # 색깔을 enum으로 선언
#      25 class Color(Enum):
#
# TypeError: rainbow_colors() takes 0 positional arguments but 1 was given

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
# Out:
# 이전 셀의 오류로 인해 셀이 취소되었습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
# Out:
# 이전 셀의 오류로 인해 셀이 취소되었습니다.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors[:]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors[:]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors[:]


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors(num_colors):
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors


rainbow_colors = rainbow_colors(7)

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors


rainbow_colors = rainbow_colors()

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def rainbow_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        pastel_color = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(pastel_color)
    # while len(colors) < num_colors:
    #     colors.extend(colors)
    return colors


rainbow_colors = rainbow_colors()

# 색깔을 enum으로 선언
class Color(Enum):
    SLEEP = rainbow_colors[0]   # 수면
    MEAL = rainbow_colors[1]    # 식사
    BUSINESS = rainbow_colors[2] # 업무
    COMMUTE = rainbow_colors[3] # 출퇴근
    REST = rainbow_colors[6]    # 휴식
    EXERCISE = rainbow_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (예시로 총 24시간 기준)
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = [Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value]

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
from enum import Enum
import matplotlib.colors as mcolors

# 한글 깨짐 방지
rc('font', family='AppleGothic')  # 폰트 설정
plt.rcParams['axes.unicode_minus'] = False  # 유니코드 마이너스 설정

# 무지개 색상을 순서대로 생성
def sched_colors():
    base_colors = list(mcolors.XKCD_COLORS.values())
    colors = []
    for color in base_colors:
        mcolor = mcolors.to_rgba(color, alpha=0.4)  # Adjust alpha for pastel effect
        colors.append(mcolor)
    return colors


# 계획표 색상 배열 가져오기
sched_colors = sched_colors()

# 색상을 enum으로 선언 (가독성)
class Color(Enum):
    SLEEP = sched_colors[0]   # 수면
    MEAL = sched_colors[1]    # 식사
    BUSINESS = sched_colors[2]# 업무
    COMMUTE = sched_colors[3] # 출퇴근
    REST = sched_colors[6]    # 휴식
    EXERCISE = sched_colors[5]# 운동

# 각 활동에 소비되는 시간을 입력 (총 24시간 기준 입니다)
# 활동배열의 처음과 끝은 수면 이어야 합니다.
activities = ['수면', '운동', '식사', '출근', '오전업무', '식사', '오후업무', '퇴근', '식사', '휴식', '']
hours = [5, 1, 1, 1, 4, 1, 5, 1, 1, 2, 2]

# 색깔 지정
colors = (Color.SLEEP.value, Color.EXERCISE.value, Color.MEAL.value, Color.COMMUTE.value, Color.BUSINESS.value, 
          Color.MEAL.value, Color.BUSINESS.value, Color.COMMUTE.value, Color.MEAL.value, 
          Color.REST.value, Color.SLEEP.value)

# 시간 값을 출력하는 autopct 함수 정의
def time_autopct(pct):
    total_hours = sum(hours)
    hours_value = int(round(pct * total_hours / 100.0))  # 퍼센트를 시간으로 변환
    # return f'{hours_value}시간'

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(hours, labels=None, autopct=time_autopct, startangle=90, colors=colors, counterclock=False)

# 원 둘레에 시간(0~24시) 표시
ax = plt.gca()  # 현재 축 가져오기
ax.set_aspect('equal')  # 원을 유지하기 위해 비율 설정

# 원 둘레에 시간 표시 (0시 ~ 23시) - 시계 방향
for hour in range(24):
    angle = 360 * (hour / 24)  # 시계 방향으로 시간에 해당하는 각도 계산
    x = np.cos(np.radians(90 - angle))  # x 좌표 (90도 이동으로 시계 방향 맞추기)
    y = np.sin(np.radians(90 - angle))  # y 좌표
    plt.text(x * 1.1, y * 1.1, f'{hour}시', ha='center', va='center')  # 원 밖에 시간 표시

# 각 활동명을 원 안에 표시
for i, (wedge, activity) in enumerate(zip(wedges, activities)):
    angle = (wedge.theta2 + wedge.theta1) / 2  # 각 활동의 중앙 각도 계산
    x = np.cos(np.radians(angle)) * 0.6  # x 좌표 (원의 60% 지점에 활동명을 표시)
    y = np.sin(np.radians(angle)) * 0.6  # y 좌표
    plt.text(x, y, activity, ha='center', va='center', fontsize=12)  # 원 안에 활동명 표시

# 그래프 제목 추가
plt.title('일일 시간 계획표')

# 그래프 보여주기
plt.show()
